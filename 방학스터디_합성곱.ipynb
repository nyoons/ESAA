# %% [markdown]
# <a href="https://colab.research.google.com/github/nyoons/ESAA/blob/main/%EB%B0%A9%ED%95%99%EC%8A%A4%ED%84%B0%EB%94%94_%ED%95%A9%EC%84%B1%EA%B3%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Part 04. 합성곱 신경망 CNN**

# %% [markdown]
# 합성곱이란?
#
# 입력 이미지에 대해 일반적으로 정방형 크기를 가지는 커널을 사용해 입력 이미지에 대한 특성을 추출하는 방법. 합성곱 연산을 통해 추출된 이미지를 **특성맵**이라고 부른다.
#
# 이미지에 필터를 적용하는 합성곱 연산. 입력 이미지의 좌측 상단부터 커널과 같은 크기를 갖도록 입력 이미지의 일부분에 커널이 겹치도록 투영해준다. 입력 이미지와 커널이 겹치는 부분에 대해 합성곱 연산을 수행.
#
# ex. 커널 사이즈가 3*3인 경우 총 9개의 가중치를 가지며 오차 역전파 시 커널의 가중치를 업데이트한다. 합성곱 신경망이 이미지 특성 추출에 효율적인 이유는 바로 커널의 공유 가중치 때문. 오차 역전파 시 커널의 그래디언트를 계산할 때 9개에 대해서만 업데이트하면 되므로 완전 연결층보다 연산량 적어진다.

# %% [markdown]
# 패딩?
#
#
# 커널 크기가 3*3, 스트라이드에서 1로 설정해도 추출된 특성맵의 사이즈는 입력 이미지 대배 가로로 2, 세로로 2씩 줄어들게 된다. 하지만 크기 줄어들지 않도록 패딩을 설정할 수 있다.

# %% [markdown]
# 풀링?
#
#
# 풀링 레이어는 추출된 특성맵에 대해 다운 샘플링하여 이미지의 크기를 축소하는 레이어. 연산량 감소, 과대적합 방지.
#
# * 최대 풀링 : 값이 큰 값이 다른 특징들을 대표한다.
# * 평균 풀링
#
# 최대 풀링 수행 시 커널의 크기가 2*2로 주어질 때 입력 이미지의 2*2 픽셀 중 최대값이 출력 값으로 선택. 평균 풀링은 평균 값.
#
# 풀링 레이어도 역시 스트라이드 값을 가지며 스트라이드를 2로 설정하면 2칸씩 건너뛰며 풀링을 수행.

# %%
# tensorflow 모듈 import
import tensorflow as tf

# %%
# mnist 손글씨 이미지 데이터 로드
mnist=tf.keras.datasets.mnist
(x_train, y_train), (x_valid, y_valid)=mnist.load_data()

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
# 샘플 이미지 출력
import matplotlib.pylab as plt

def plot_image(data, idx):
  plt.figure(figsize=(5,5))
  plt.imshow(data[idx], cmap='gray')
  plt.axis('off')
  plt.show()

plot_image(x_train, 0)

# %%
print(x_train.min(), x_train.max())
print(x_valid.min(), x_valid.max())
# Out:
# 0 255
# 0 255

# %%
# 정규화
x_train=x_train/255.0
x_valid=x_valid/255.0

print(x_train.min(), x_train.max())
print(x_valid.min(), x_valid.max())
# Out:
# 0.0 1.0
# 0.0 1.0

# %%
# 채널 추가
print(x_train.shape, x_valid.shape)

x_train_in=x_train[..., tf.newaxis]
x_valid_in=x_valid[..., tf.newaxis]

print(x_train_in.shape, x_valid_in.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %% [markdown]
# 합성곱 레이어 1개, 풀링 레이어 1개를 적용하는 간단한 모델 생성해보자.

# %%
# Sequential API를 사용해 샘플 모델 생성
model=tf.keras.Sequential([
    #Convolution 적용 (32 filters)
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1), name='conv'),
    #max pooling 적용
    tf.keras.layers.MaxPooling2D((2,2), name='pool'),
    #classifier 출력층
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련
history=model.fit(x_train_in, y_train, validation_data=(x_valid_in, y_valid), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.2026 - accuracy: 0.9428 - val_loss: 0.0839 - val_accuracy: 0.9738
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0773 - accuracy: 0.9776 - val_loss: 0.0728 - val_accuracy: 0.9769
# Epoch 3/10
# 1875/1875 [==============================] - 40s 21ms/step - loss: 0.0599 - accuracy: 0.9826 - val_loss: 0.0545 - val_accuracy: 0.9818
# Epoch 4/10
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0504 - accuracy: 0.9845 - val_loss: 0.0586 - val_accuracy: 0.9799
# Epoch 5/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0425 - accuracy: 0.9872 - val_loss: 0.0549 - val_accuracy: 0.9818
# Epoch 6/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0360 - accuracy: 0.9894 - val_loss: 0.0579 - val_accuracy: 0.9824
# Epoch 7/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0309 - accuracy: 0.9904 - val_loss: 0.0542 - val_accuracy: 0.9845
# Epoch 8/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0261 - accuracy: 0.9921 - val_loss: 0.0600 - val_accuracy: 0.9827
# Epoch 9/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0222 - accuracy: 0.9926 - val_loss: 0.0551 - val_accuracy: 0.9838
# Epoch 10/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0192 - accuracy: 0.9937 - val_loss: 0.0592 - val_accuracy: 0.9821

# %%
# evaluate도 하자
model.evaluate(x_valid_in, y_valid)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0592 - accuracy: 0.9821
# [0.059200648218393326, 0.9821000099182129]

# %%
def plot_loss_acc(history, epoch):
  loss, val_loss=history.history['loss'], history.history['val_loss']
  acc, val_acc=history.history['accuracy'], history.history['val_accuracy']

  fig, axes=plt.subplots(1, 2, figsize=(12, 4))

  axes[0].plot(range(1, epoch+1), loss, label='Training')
  axes[0].plot(range(1, epoch+1), val_loss, label='Validation')
  axes[0].legend(loc='best')
  axes[0].set_title('Loss')

  axes[1].plot(range(1, epoch+1), loss, label='Training')
  axes[1].plot(range(1, epoch+1), val_loss, label='Validation')
  axes[1].legend(loc='best')
  axes[1].set_title('Accuracy')

  plt.show()

plot_loss_acc(history, 10)

# %% [markdown]
# 4 epoch 이후로는 과대적합.

# %%
# 모델 구조
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv (Conv2D)               (None, 26, 26, 32)        320
#
#  pool (MaxPooling2D)         (None, 13, 13, 32)        0
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 10)                54090
#
# =================================================================
# Total params: 54,410
# Trainable params: 54,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 레이어
model.layers
# Out:
# [<keras.layers.convolutional.conv2d.Conv2D at 0x7b85abbe0d30>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7b85af2c9f00>,
#  <keras.layers.reshaping.flatten.Flatten at 0x7b85af2c8e20>,
#  <keras.layers.core.dense.Dense at 0x7b85af2cb460>]

# %%
# 첫 번재 레이어 가중치
model.layers[0].weights
# Out:
# [<tf.Variable 'conv/kernel:0' shape=(3, 3, 1, 32) dtype=float32, numpy=
#  array([[[[ 0.38408858, -0.6229579 , -0.8669987 , -0.45034415,
#             0.18312478,  0.06636839,  0.14994988,  0.16940624,
#            -1.309891  , -0.02400214,  0.40332517,  0.3143791 ,
#            -0.92920715, -0.3423832 ,  0.421272  , -0.5171512 ,
#             0.3450332 , -0.13864155, -0.85303175,  0.10827309,
#            -0.26903084, -0.31015784, -0.91697496,  0.10675513,
#            -0.63571477, -0.04019451,  0.24811615, -0.38913003,
#             0.2102158 ,  0.1347861 , -0.69076735,  0.02545088]],
#
#          [[ 0.6279116 , -0.24845377, -0.33692393, -0.07368968,
#             0.15507084,  0.5334468 ,  0.25792104, -0.24598922,
#            -0.7870958 ,  0.1958569 ,  0.29333702, -0.03492865,
#            -1.0109365 , -0.17743775,  0.13398732,  0.31477523,
#            -0.06093553,  0.36630943, -0.6749535 ,  0.3827089 ,
#            -0.25633   , -0.8063542 , -0.75152856,  0.14910437,
#            -0.59667414,  0.5390966 ,  0.00162295,  0.04242497,
#            -0.55085915,  0.43792927,  0.01521671, -0.25565955]],
#
#          [[ 0.19809484,  0.22312333,  0.49098337,  0.20317036,
#             0.1777749 ,  0.2189056 , -0.1996732 , -0.5472382 ,
#            -0.97265625,  0.6217221 , -0.7263345 , -0.3190998 ,
#            -0.6035073 ,  0.20698297, -0.5247273 ,  0.10216855,
#            -0.39067972,  0.01060699, -0.41630286,  0.5488556 ,
#             0.18078057, -0.33348855, -1.0104928 , -0.60001683,
#            -0.38157576,  0.68389726, -0.262542  ,  0.25470874,
#             0.10702272,  0.22469327,  0.458667  ,  0.15289019]]],
#
#
#         [[[ 0.22084174,  0.11262264, -0.50504184,  0.18865739,
#             0.18546924, -0.6010867 , -0.14822762,  0.30381542,
#             0.2528428 , -0.86833066,  0.46368983,  0.40411997,
#            -0.85389024, -0.24095514, -0.19952038,  0.1184123 ,
#             0.03265278, -0.51474816, -0.67663205, -0.06364758,
#             0.4042984 ,  0.44147247, -0.892962  ,  0.19630916,
#             0.09246219, -0.67388207,  0.05300154, -0.20747472,
#            -0.3140249 , -0.1475069 , -0.97594154, -0.5874701 ]],
#
#          [[ 0.3523563 ,  0.40169525,  0.01042075,  0.2376042 ,
#             0.11310741,  0.16662091,  0.2944464 , -0.1059464 ,
#             0.17251767, -0.60402715,  0.14511196, -0.28634974,
#             0.38900387,  0.44746745,  0.3204185 ,  0.28717822,
#            -0.0921735 ,  0.16813324,  0.2496697 ,  0.29095903,
#             0.25860777,  0.16586648,  0.12922598,  0.38799608,
#            -0.15302272,  0.23847087,  0.2920227 ,  0.17955115,
#            -0.0469298 ,  0.17627653, -0.09174524, -0.19023214]],
#
#          [[-0.7875067 ,  0.26126572,  0.45978403,  0.06593544,
#             0.30405694, -0.04662002, -0.26094154, -0.47613072,
#            -1.0587125 ,  0.7540654 , -0.92250293, -0.29447982,
#             0.65292984, -0.08233501, -0.02027133, -0.4107791 ,
#            -0.07070571, -0.04831205, -0.03038207,  0.00954334,
#             0.19309366, -0.08445254,  0.10546283, -0.77173185,
#            -0.41267526,  0.3173113 , -0.14197133, -0.01432294,
#             0.22951928,  0.24762759,  0.44705486,  0.44977212]]],
#
#
#         [[[-0.63588303,  0.23165838, -0.35719615,  0.18563727,
#            -0.58568436, -0.48891267, -0.36416778,  0.34573373,
#             0.69571364, -0.13316925,  0.5049244 , -0.05182355,
#            -0.32372174,  0.23381309, -0.19588797,  0.09399489,
#            -0.07471808, -0.29610276, -0.05841044, -0.8046607 ,
#             0.10011289,  0.44799176,  0.15464419,  0.40479314,
#             0.47168842, -1.334403  , -0.40927327,  0.3736696 ,
#             0.26106462, -0.46716172, -0.72660357, -0.42207944]],
#
#          [[-0.9924995 , -0.10376963,  0.09888446,  0.02378402,
#            -0.32350874,  0.08137164,  0.18068567,  0.47585332,
#             0.44114703, -1.0284013 , -0.4130807 ,  0.17849791,
#             0.5881701 ,  0.23475319,  0.02960994,  0.09053984,
#             0.2977052 ,  0.376559  ,  0.3770914 , -0.70598483,
#            -0.47883815,  0.24720089,  0.5391414 ,  0.2516934 ,
#             0.57305694, -0.82833934,  0.19974972,  0.02031772,
#             0.32887852, -0.6010308 , -0.2850434 ,  0.0292528 ]],
#
#          [[-0.98279595, -0.43789315,  0.25718465, -0.4282931 ,
#            -0.45249557,  0.29932797,  0.27353725,  0.2405229 ,
#            -0.36176088, -0.07276888, -1.2957044 ,  0.26910645,
#             0.2274823 , -0.5731891 ,  0.37617213, -0.23928759,
#             0.257788  ,  0.14711827,  0.34674072, -0.66818357,
#            -0.09375532,  0.03081486,  0.42149416, -0.5763007 ,
#             0.1970291 , -1.11457   ,  0.19493954, -0.13255776,
#            -0.23837231,  0.09877023,  0.43050906,  0.3929653 ]]]],
#        dtype=float32)>,
#  <tf.Variable 'conv/bias:0' shape=(32,) dtype=float32, numpy=
#  array([-0.01694636, -0.14293379, -0.07016502, -0.2104453 , -0.09174736,
#         -0.3634936 , -0.2540448 , -0.25158322,  0.20215514, -0.01618042,
#         -0.0168082 , -0.30169532,  0.03631248, -0.13122627, -0.32196692,
#         -0.1320552 , -0.31789646, -0.33584338, -0.00765495, -0.0735469 ,
#         -0.07848752, -0.0475586 , -0.01657158, -0.11806636, -0.07123096,
#         -0.00937546, -0.25790098, -0.30720365, -0.12148692, -0.19084337,
#         -0.06817953, -0.08587541], dtype=float32)>]

# %%
# 첫 번째 레이어 커널 가중치
model.layers[0].kernel
# Out:
# <tf.Variable 'conv/kernel:0' shape=(3, 3, 1, 32) dtype=float32, numpy=
# array([[[[ 0.38408858, -0.6229579 , -0.8669987 , -0.45034415,
#            0.18312478,  0.06636839,  0.14994988,  0.16940624,
#           -1.309891  , -0.02400214,  0.40332517,  0.3143791 ,
#           -0.92920715, -0.3423832 ,  0.421272  , -0.5171512 ,
#            0.3450332 , -0.13864155, -0.85303175,  0.10827309,
#           -0.26903084, -0.31015784, -0.91697496,  0.10675513,
#           -0.63571477, -0.04019451,  0.24811615, -0.38913003,
#            0.2102158 ,  0.1347861 , -0.69076735,  0.02545088]],
#
#         [[ 0.6279116 , -0.24845377, -0.33692393, -0.07368968,
#            0.15507084,  0.5334468 ,  0.25792104, -0.24598922,
#           -0.7870958 ,  0.1958569 ,  0.29333702, -0.03492865,
#           -1.0109365 , -0.17743775,  0.13398732,  0.31477523,
#           -0.06093553,  0.36630943, -0.6749535 ,  0.3827089 ,
#           -0.25633   , -0.8063542 , -0.75152856,  0.14910437,
#           -0.59667414,  0.5390966 ,  0.00162295,  0.04242497,
#           -0.55085915,  0.43792927,  0.01521671, -0.25565955]],
#
#         [[ 0.19809484,  0.22312333,  0.49098337,  0.20317036,
#            0.1777749 ,  0.2189056 , -0.1996732 , -0.5472382 ,
#           -0.97265625,  0.6217221 , -0.7263345 , -0.3190998 ,
#           -0.6035073 ,  0.20698297, -0.5247273 ,  0.10216855,
#           -0.39067972,  0.01060699, -0.41630286,  0.5488556 ,
#            0.18078057, -0.33348855, -1.0104928 , -0.60001683,
#           -0.38157576,  0.68389726, -0.262542  ,  0.25470874,
#            0.10702272,  0.22469327,  0.458667  ,  0.15289019]]],
#
#
#        [[[ 0.22084174,  0.11262264, -0.50504184,  0.18865739,
#            0.18546924, -0.6010867 , -0.14822762,  0.30381542,
#            0.2528428 , -0.86833066,  0.46368983,  0.40411997,
#           -0.85389024, -0.24095514, -0.19952038,  0.1184123 ,
#            0.03265278, -0.51474816, -0.67663205, -0.06364758,
#            0.4042984 ,  0.44147247, -0.892962  ,  0.19630916,
#            0.09246219, -0.67388207,  0.05300154, -0.20747472,
#           -0.3140249 , -0.1475069 , -0.97594154, -0.5874701 ]],
#
#         [[ 0.3523563 ,  0.40169525,  0.01042075,  0.2376042 ,
#            0.11310741,  0.16662091,  0.2944464 , -0.1059464 ,
#            0.17251767, -0.60402715,  0.14511196, -0.28634974,
#            0.38900387,  0.44746745,  0.3204185 ,  0.28717822,
#           -0.0921735 ,  0.16813324,  0.2496697 ,  0.29095903,
#            0.25860777,  0.16586648,  0.12922598,  0.38799608,
#           -0.15302272,  0.23847087,  0.2920227 ,  0.17955115,
#           -0.0469298 ,  0.17627653, -0.09174524, -0.19023214]],
#
#         [[-0.7875067 ,  0.26126572,  0.45978403,  0.06593544,
#            0.30405694, -0.04662002, -0.26094154, -0.47613072,
#           -1.0587125 ,  0.7540654 , -0.92250293, -0.29447982,
#            0.65292984, -0.08233501, -0.02027133, -0.4107791 ,
#           -0.07070571, -0.04831205, -0.03038207,  0.00954334,
#            0.19309366, -0.08445254,  0.10546283, -0.77173185,
#           -0.41267526,  0.3173113 , -0.14197133, -0.01432294,
#            0.22951928,  0.24762759,  0.44705486,  0.44977212]]],
#
#
#        [[[-0.63588303,  0.23165838, -0.35719615,  0.18563727,
#           -0.58568436, -0.48891267, -0.36416778,  0.34573373,
#            0.69571364, -0.13316925,  0.5049244 , -0.05182355,
#           -0.32372174,  0.23381309, -0.19588797,  0.09399489,
#           -0.07471808, -0.29610276, -0.05841044, -0.8046607 ,
#            0.10011289,  0.44799176,  0.15464419,  0.40479314,
#            0.47168842, -1.334403  , -0.40927327,  0.3736696 ,
#            0.26106462, -0.46716172, -0.72660357, -0.42207944]],
#
#         [[-0.9924995 , -0.10376963,  0.09888446,  0.02378402,
#           -0.32350874,  0.08137164,  0.18068567,  0.47585332,
#            0.44114703, -1.0284013 , -0.4130807 ,  0.17849791,
#            0.5881701 ,  0.23475319,  0.02960994,  0.09053984,
#            0.2977052 ,  0.376559  ,  0.3770914 , -0.70598483,
#           -0.47883815,  0.24720089,  0.5391414 ,  0.2516934 ,
#            0.57305694, -0.82833934,  0.19974972,  0.02031772,
#            0.32887852, -0.6010308 , -0.2850434 ,  0.0292528 ]],
#
#         [[-0.98279595, -0.43789315,  0.25718465, -0.4282931 ,
#           -0.45249557,  0.29932797,  0.27353725,  0.2405229 ,
#           -0.36176088, -0.07276888, -1.2957044 ,  0.26910645,
#            0.2274823 , -0.5731891 ,  0.37617213, -0.23928759,
#            0.257788  ,  0.14711827,  0.34674072, -0.66818357,
#           -0.09375532,  0.03081486,  0.42149416, -0.5763007 ,
#            0.1970291 , -1.11457   ,  0.19493954, -0.13255776,
#           -0.23837231,  0.09877023,  0.43050906,  0.3929653 ]]]],
#       dtype=float32)>

# %%
# 샘플 이미지의 레이어별 출력을 리스트에 추가 (첫 번째, 두 번째 레이어)
activator=tf.keras.Model(inputs=model.input, outputs=[layer.output for layer in model.layers[:2]])
activations=activator.predict(x_train_in[0][tf.newaxis, ...])

len(activations)
# Out:
# 1/1 [==============================] - 0s 130ms/step
# 2

# %% [markdown]
# 첫번째 레이어 시각화

# %%
# 첫 번재 레이어 conv의 출력층
conv_activation=activations[0]
conv_activation.shape
# Out:
# (1, 26, 26, 32)

# %%
# Convolution 시각화
fig, axes=plt.subplots(4, 8)
fig.set_size_inches(10, 5)

for i in range(32):
  axes[i//8, i%8].matshow(conv_activation[0, :, :, i], cmap='viridis')
  axes[i//8, i%8].set_title('kernel %s'%str(i), fontsize=10)
  plt.setp(axes[i//8, i%8].get_xticklabels(), visible=False)
  plt.setp(axes[i//8, i%8].get_yticklabels(), visible=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# 두번째 레이어 시각화

# %%
# 두번째 레이어 pool 출력층
pooling_activation=activations[1]
print(pooling_activation.shape)
# Out:
# (1, 13, 13, 32)

# %%
# 시각화
fig, axes=plt.subplots(4, 8)
fig.set_size_inches(10, 5)

for i in range(32):
  axes[i//8, i%8].matshow(pooling_activation[0, :, :, i], cmap='viridis')
  axes[i//8, i%8].set_title('kernel %s'%str(i), fontsize=10)
  plt.setp(axes[i//8, i%8].get_xticklabels(), visible=False)
  plt.setp(axes[i//8, i%8].get_yticklabels(), visible=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# **복잡한 모델을 생성해보자.**

# %%
import tensorflow as tf
import numpy as np

#mnist 손글씨 이미지 데이터 로드
mnist=tf.keras.datasets.mnist
(x_train, y_train), (x_valid, y_valid)=mnist.load_data()

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
# 새로운 출력 값 배열 생성 (홀수 : 1, 짝수 : 0)
y_train_odd=[]
for y in y_train:
  if y%2==0:
    y_train_odd.append(0)
  else:
    y_train_odd.append(1)

y_train_odd=np.array(y_train_odd)
y_train_odd.shape
# Out:
# (60000,)

# %%
# Validation 데이터셋 처리
y_valid_odd=[]
for y in y_valid:
  if y%2==0:
    y_valid_odd.append(0)
  else:
    y_valid_odd.append(1)

y_valid_odd=np.array(y_valid_odd)
y_valid_odd.shape
# Out:
# (10000,)

# %%
# 정규화
x_train=x_train/255.0
x_valid=x_valid/255.0

# 채널 추가
x_train_in=tf.expand_dims(x_train, -1)
x_valid_in=tf.expand_dims(x_valid, -1)

print(x_train_in.shape, x_valid_in.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %%
# Functional API 를 사용하여 모델 생성

inputs=tf.keras.layers.Input(shape=(28, 28, 1))

conv=tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(inputs)
pool=tf.keras.layers.MaxPooling2D((2,2))(conv)
flat=tf.keras.layers.Flatten()(pool)

flat_inputs=tf.keras.layers.Flatten()(inputs)
concat=tf.keras.layers.Concatenate()([flat, flat_inputs])
outputs=tf.keras.layers.Dense(10, activation='softmax')(concat)

model=tf.keras.models.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 26, 26, 32)   320         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 13, 13, 32)   0           ['conv2d[0][0]']
#
#  flatten_1 (Flatten)            (None, 5408)         0           ['max_pooling2d[0][0]']
#
#  flatten_2 (Flatten)            (None, 784)          0           ['input_1[0][0]']
#
#  concatenate (Concatenate)      (None, 6192)         0           ['flatten_1[0][0]',
#                                                                   'flatten_2[0][0]']
#
#  dense_1 (Dense)                (None, 10)           61930       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 62,250
# Trainable params: 62,250
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 모델 구조 출력 및 이미지 파일로 저장
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, to_file='functional_cnn.png')

# %%
# 모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 모델 훈련
history=model.fit(x_train_in, y_train, validation_data=(x_valid, y_valid), epochs=10)

# 모델 성능
val_loss, val_acc=model.evaluate(x_valid_in, y_valid)
print(val_loss, val_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.2071 - accuracy: 0.9413 - val_loss: 0.0868 - val_accuracy: 0.9733
# Epoch 2/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0764 - accuracy: 0.9775 - val_loss: 0.0681 - val_accuracy: 0.9781
# Epoch 3/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0597 - accuracy: 0.9826 - val_loss: 0.0548 - val_accuracy: 0.9822
# Epoch 4/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0493 - accuracy: 0.9850 - val_loss: 0.0575 - val_accuracy: 0.9809
# Epoch 5/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0409 - accuracy: 0.9876 - val_loss: 0.0585 - val_accuracy: 0.9814
# Epoch 6/10
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0333 - accuracy: 0.9899 - val_loss: 0.0535 - val_accuracy: 0.9834
# Epoch 7/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.0539 - val_accuracy: 0.9837
# Epoch 8/10
# 1875/1875 [==============================] - 37s 20ms/step - loss: 0.0230 - accuracy: 0.9931 - val_loss: 0.0580 - val_accuracy: 0.9834
# Epoch 9/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.0596 - val_accuracy: 0.9824
# Epoch 10/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.0597 - val_accuracy: 0.9833
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0597 - accuracy: 0.9833
# 0.059710241854190826 0.983299970626831

# %% [markdown]
# 이번엔 다중 출력 분류 모델을 만들어보자.

# %%
# Functional API를 사용해 모델 생성

inputs=tf.keras.layers.Input(shape=(28, 28, 1), name='inputs')

conv=tf.keras.layers.Conv2D(32, (3, 3), activation='relu', name='conv2d_layer')(inputs)
pool=tf.keras.layers.MaxPooling2D((2,2), name='maxpool_layer')(conv)
flat=tf.keras.layers.Flatten(name='flatten_layer')(pool)

flat_inputs=tf.keras.layers.Flatten()(inputs)
concat=tf.keras.layers.Concatenate()([flat, flat_inputs])
digit_outputs=tf.keras.layers.Dense(10, activation='softmax', name='digit_dense')(concat)

odd_outputs=tf.keras.layers.Dense(1, activation='sigmoid', name='odd_dense')(flat_inputs)

model=tf.keras.models.Model(inputs=inputs, outputs=[digit_outputs, odd_outputs])

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, 28, 28, 1)]  0           []
#
#  conv2d_layer (Conv2D)          (None, 26, 26, 32)   320         ['inputs[0][0]']
#
#  maxpool_layer (MaxPooling2D)   (None, 13, 13, 32)   0           ['conv2d_layer[0][0]']
#
#  flatten_layer (Flatten)        (None, 5408)         0           ['maxpool_layer[0][0]']
#
#  flatten_3 (Flatten)            (None, 784)          0           ['inputs[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 6192)         0           ['flatten_layer[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  digit_dense (Dense)            (None, 10)           61930       ['concatenate_1[0][0]']
#
#  odd_dense (Dense)              (None, 1)            785         ['flatten_3[0][0]']
#
# ==================================================================================================
# Total params: 63,035
# Trainable params: 63,035
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 모델의 입력과 출력을 나타내는 텐서
print(model.input)
print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name='inputs'), name='inputs', description="created by layer 'inputs'")
# [<KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'digit_dense')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'odd_dense')>]

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, to_file='multi_output_cnn.png')

# %%
# 모델 컴파일
model.compile(optimizer='adam',
              loss={'digit_dense': 'sparse_categorical_crossentropy', 'odd_dense':'binary_crossentropy'},
              loss_weights={'digit_dense':1, 'odd_dense':0.5}, # loss = 1.0 * sparse_categorical_crossentropy + 0.5 * binary_crossentropy
              metrics=['accuracy'])

# 모델 훈련
history=model.fit({'inputs':x_train_in},
                  {'digit_dense':y_train, 'odd_dense':y_train_odd},
                   validation_data=({'inputs':x_valid_in}, {'digit_dense':y_valid, 'odd_dense':y_valid_odd}), epochs=10)

# 모델 성능
model.evaluate({'inputs':x_valid_in}, {'digit_dense':y_valid, 'odd_dense':y_valid_odd})
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 42s 22ms/step - loss: 0.3702 - digit_dense_loss: 0.2069 - odd_dense_loss: 0.3267 - digit_dense_accuracy: 0.9404 - odd_dense_accuracy: 0.8629 - val_loss: 0.2240 - val_digit_dense_loss: 0.0859 - val_odd_dense_loss: 0.2761 - val_digit_dense_accuracy: 0.9750 - val_odd_dense_accuracy: 0.8856
# Epoch 2/10
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.2134 - digit_dense_loss: 0.0775 - odd_dense_loss: 0.2719 - digit_dense_accuracy: 0.9772 - odd_dense_accuracy: 0.8907 - val_loss: 0.2000 - val_digit_dense_loss: 0.0683 - val_odd_dense_loss: 0.2634 - val_digit_dense_accuracy: 0.9792 - val_odd_dense_accuracy: 0.8952
# Epoch 3/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.1912 - digit_dense_loss: 0.0598 - odd_dense_loss: 0.2628 - digit_dense_accuracy: 0.9823 - odd_dense_accuracy: 0.8954 - val_loss: 0.1901 - val_digit_dense_loss: 0.0606 - val_odd_dense_loss: 0.2590 - val_digit_dense_accuracy: 0.9804 - val_odd_dense_accuracy: 0.8992
# Epoch 4/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.1777 - digit_dense_loss: 0.0483 - odd_dense_loss: 0.2589 - digit_dense_accuracy: 0.9855 - odd_dense_accuracy: 0.8977 - val_loss: 0.1908 - val_digit_dense_loss: 0.0623 - val_odd_dense_loss: 0.2570 - val_digit_dense_accuracy: 0.9807 - val_odd_dense_accuracy: 0.9008
# Epoch 5/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.1698 - digit_dense_loss: 0.0413 - odd_dense_loss: 0.2570 - digit_dense_accuracy: 0.9871 - odd_dense_accuracy: 0.8987 - val_loss: 0.1895 - val_digit_dense_loss: 0.0604 - val_odd_dense_loss: 0.2582 - val_digit_dense_accuracy: 0.9795 - val_odd_dense_accuracy: 0.8982
# Epoch 6/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.1618 - digit_dense_loss: 0.0340 - odd_dense_loss: 0.2556 - digit_dense_accuracy: 0.9895 - odd_dense_accuracy: 0.8996 - val_loss: 0.1858 - val_digit_dense_loss: 0.0579 - val_odd_dense_loss: 0.2558 - val_digit_dense_accuracy: 0.9815 - val_odd_dense_accuracy: 0.9013
# Epoch 7/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.1566 - digit_dense_loss: 0.0291 - odd_dense_loss: 0.2550 - digit_dense_accuracy: 0.9910 - odd_dense_accuracy: 0.9006 - val_loss: 0.1849 - val_digit_dense_loss: 0.0572 - val_odd_dense_loss: 0.2555 - val_digit_dense_accuracy: 0.9830 - val_odd_dense_accuracy: 0.9014
# Epoch 8/10
# 1875/1875 [==============================] - 39s 21ms/step - loss: 0.1522 - digit_dense_loss: 0.0251 - odd_dense_loss: 0.2541 - digit_dense_accuracy: 0.9922 - odd_dense_accuracy: 0.9008 - val_loss: 0.1933 - val_digit_dense_loss: 0.0652 - val_odd_dense_loss: 0.2563 - val_digit_dense_accuracy: 0.9816 - val_odd_dense_accuracy: 0.9014
# Epoch 9/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.1484 - digit_dense_loss: 0.0214 - odd_dense_loss: 0.2540 - digit_dense_accuracy: 0.9933 - odd_dense_accuracy: 0.9003 - val_loss: 0.1888 - val_digit_dense_loss: 0.0585 - val_odd_dense_loss: 0.2607 - val_digit_dense_accuracy: 0.9832 - val_odd_dense_accuracy: 0.9014
# Epoch 10/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.1454 - digit_dense_loss: 0.0186 - odd_dense_loss: 0.2536 - digit_dense_accuracy: 0.9941 - odd_dense_accuracy: 0.9010 - val_loss: 0.1881 - val_digit_dense_loss: 0.0600 - val_odd_dense_loss: 0.2561 - val_digit_dense_accuracy: 0.9833 - val_odd_dense_accuracy: 0.9015
# 313/313 [==============================] - 2s 7ms/step - loss: 0.1881 - digit_dense_loss: 0.0600 - odd_dense_loss: 0.2561 - digit_dense_accuracy: 0.9833 - odd_dense_accuracy: 0.9015
# [0.18810072541236877,
#  0.060034703463315964,
#  0.256132036447525,
#  0.983299970626831,
#  0.9014999866485596]

# %%
# 샘플 이미지 출력
import matplotlib.pylab as plt

def plot_image(data, idx):
  plt.figure(figsize=(5,5))
  plt.imshow(data[idx])
  plt.axis('off')
  plt.show()

plot_image(x_valid, 0)
